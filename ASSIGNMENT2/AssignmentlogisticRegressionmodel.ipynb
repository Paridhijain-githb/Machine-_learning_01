# %% [markdown]
# Build classification models on the Mobile Price Classification dataset to predict the price range of a mobile phone given its specification features.

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
path = r"C:\Users\admin\Downloads\train.csv"
import pandas as pd
df = pd.read_csv(path)
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.shape
# Out:
# (2000, 21)

# %%
df['price_range'].unique()
# Out:
# array([1, 2, 3, 0])

# %%
# check for missing data
df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
# check for duplicated rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# Separate X and Y features
# Y : Species X : all remaining features, sepal length/width, petal length/width

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
X = df.drop(columns=['price_range'])
Y = df[['price_range']]

# %%
X.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
Y.head()
# Out:
#    price_range
# 0            1
# 1            2
# 2            2
# 3            2
# 4            1

# %% [markdown]
# Data Preprocessing and Data Cleaning

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
pre = make_pipeline(
    SimpleImputer(strategy='median'),
    StandardScaler()
).set_output(transform='pandas')

# %%
X_pre = pre.fit_transform(X)
X_pre.head()
# Out:
#    battery_power      blue  clock_speed  dual_sim        fc    four_g  \
# 0      -0.902597 -0.990050     0.830779 -1.019184 -0.762495 -1.043966
# 1      -0.495139  1.010051    -1.253064  0.981177 -0.992890  0.957886
# 2      -1.537686  1.010051    -1.253064  0.981177 -0.532099  0.957886
# 3      -1.419319  1.010051     1.198517 -1.019184 -0.992890 -1.043966
# 4       1.325906  1.010051    -0.395011 -1.019184  2.002254  0.957886
#
#    int_memory     m_dep  mobile_wt   n_cores        pc  px_height  px_width  \
# 0   -1.380644  0.340740   1.349249 -1.101971 -1.305750  -1.408949 -1.146784
# 1    1.155024  0.687548  -0.120059 -0.664768 -0.645989   0.585778  1.704465
# 2    0.493546  1.381165   0.134244  0.209639 -0.645989   1.392684  1.074968
# 3   -1.215274  1.034357  -0.261339  0.646842 -0.151168   1.286750  1.236971
# 4    0.658915  0.340740   0.021220 -1.101971  0.673534   1.268718 -0.091452
#
#         ram      sc_h      sc_w  talk_time   three_g  touch_screen      wifi
# ...

# %% [markdown]
# Train Test Split
# rate at which you can divide:
#
# 100%
#
# 60 % training 40% testing
#
# 70% training 30% testing
#
# 80% training 20% testing

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X_pre,Y,train_size=0.7,test_size=0.3,random_state=21)

# %%
xtrain.head()
# Out:
#       battery_power      blue  clock_speed  dual_sim        fc    four_g  \
# 1200      -1.612805 -0.990050     1.075937 -1.019184 -0.762495 -1.043966
# 622       -0.030772 -0.990050    -1.007906  0.981177 -0.992890  0.957886
# 658        1.564918  1.010051    -0.517590 -1.019184  2.002254  0.957886
# 1990       0.861540  1.010051     1.075937 -1.019184  0.850275  0.957886
# 310        0.399450  1.010051    -0.027274  0.981177  0.159088 -1.043966
#
#       int_memory     m_dep  mobile_wt   n_cores        pc  px_height  \
# 1200   -0.002563 -0.699686  -1.476344  0.646842  1.663176  -1.345839
# 622    -1.656260  0.340740  -0.063548  1.084046 -1.470690  -0.964925
# 658     0.989655 -1.046495   1.094945  0.646842  1.168355  -0.617820
# 1990    0.217930  1.034357  -1.561112 -1.539175 -0.151168   0.220642
# 310     0.658915 -0.006069   1.123201 -1.101971 -0.645989  -1.354854
#
#       px_width       ram      sc_h      sc_w  talk_time   three_g  \
# ...

# %%
xtrain.index
# Out:
# Index([1200,  622,  658, 1990,  310,  884,  937, 1390,  668, 1232,
#        ...
#         610,  700, 1443, 1144,  368,   48,  772, 1848, 1231,  969],
#       dtype='int64', length=1400)

# %%
xtest.head()
# Out:
#       battery_power      blue  clock_speed  dual_sim        fc    four_g  \
# 541       -1.014136 -0.990050    -0.395011  0.981177 -0.762495  0.957886
# 1211      -1.196241  1.010051     0.095305 -1.019184  0.619880  0.957886
# 1862      -0.445060 -0.990050     1.443675 -1.019184 -0.301703 -1.043966
# 1094      -1.253148  1.010051    -0.027274 -1.019184 -0.992890 -1.043966
# 465        0.784145  1.010051     0.095305 -1.019184  0.159088  0.957886
#
#       int_memory     m_dep  mobile_wt   n_cores        pc  px_height  \
# 541     0.328176  0.340740   1.010178 -0.227564 -0.481048   1.309289
# 1211   -1.656260 -0.352878   1.151457  1.521249 -0.151168   1.275480
# 1862   -0.167933 -1.046495  -1.617624  1.521249  1.168355   0.545207
# 1094   -1.656260  1.727974  -1.448088 -0.664768 -1.305750  -0.843213
# 465     0.548669  1.034357  -0.628666 -0.664768  0.013773  -0.834197
#
#       px_width       ram      sc_h      sc_w  talk_time   three_g  \
# ...

# %%
ytrain.head()
# Out:
#       price_range
# 1200            0
# 622             2
# 658             3
# 1990            0
# 310             3

# %%
ytest.head()
# Out:
#       price_range
# 541             3
# 1211            0
# 1862            0
# 1094            0
# 465             3

# %% [markdown]
# Build the model

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
model.classes_
# Out:
# array([0, 1, 2, 3])

# %%
ypred_train = model.predict(xtrain)

# %%
yprob_train = model.predict_proba(xtrain)

# %%
yprob_train[0]
# Out:
# array([9.98488713e-01, 1.51125965e-03, 2.69711636e-08, 6.86065896e-16])

# %%
ytrain.head()
# Out:
#       price_range
# 1200            0
# 622             2
# 658             3
# 1990            0
# 310             3

# %%
xtrain.head()
# Out:
#       battery_power      blue  clock_speed  dual_sim        fc    four_g  \
# 1200      -1.612805 -0.990050     1.075937 -1.019184 -0.762495 -1.043966
# 622       -0.030772 -0.990050    -1.007906  0.981177 -0.992890  0.957886
# 658        1.564918  1.010051    -0.517590 -1.019184  2.002254  0.957886
# 1990       0.861540  1.010051     1.075937 -1.019184  0.850275  0.957886
# 310        0.399450  1.010051    -0.027274  0.981177  0.159088 -1.043966
#
#       int_memory     m_dep  mobile_wt   n_cores        pc  px_height  \
# 1200   -0.002563 -0.699686  -1.476344  0.646842  1.663176  -1.345839
# 622    -1.656260  0.340740  -0.063548  1.084046 -1.470690  -0.964925
# 658     0.989655 -1.046495   1.094945  0.646842  1.168355  -0.617820
# 1990    0.217930  1.034357  -1.561112 -1.539175 -0.151168   0.220642
# 310     0.658915 -0.006069   1.123201 -1.101971 -0.645989  -1.354854
#
#       px_width       ram      sc_h      sc_w  talk_time   three_g  \
# ...

# %% [markdown]
# Model Evaluation

# %%
model.score(xtest,ytest)
# Out:
# 0.9583333333333334

# %%
model.score(xtrain,ytrain)
# Out:
# 0.9728571428571429

# %% [markdown]
# Confusion Matrix

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(model,xtest,ytest)

# %% [markdown]
# Classification Report

# %%
ypred_test = model.predict(xtest)

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest,ypred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98       166
#            1       0.93      0.95      0.94       149
#            2       0.95      0.93      0.94       149
#            3       0.96      0.99      0.97       136
#
#     accuracy                           0.96       600
#    macro avg       0.96      0.96      0.96       600
# weighted avg       0.96      0.96      0.96       600

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest,ypred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98       166
#            1       0.93      0.95      0.94       149
#            2       0.95      0.93      0.94       149
#            3       0.96      0.99      0.97       136
#
#     accuracy                           0.96       600
#    macro avg       0.96      0.96      0.96       600
# weighted avg       0.96      0.96      0.96       600

# %% [markdown]
# All the scores are greater than 80%(0.80), we can consider this model for final model building

# %%
path2 = r"C:\Users\admin\Downloads\test.csv"
xnew = pd.read_csv(path2)
xnew.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
xnew.isna().sum()
# Out:
# id               0
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# dtype: int64

# %% [markdown]
# Preprocess and clean out of sample data

# %%
model.predict(xnew)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 model.predict(xnew)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\linear_model\_base.py:375, in LinearClassifierMixin.predict(self, X)
#     361 """
#     362 Predict class labels for samples in X.
#     363
#    (...)    372     Vector containing the class labels for each sample.
#     373 """
#     374 xp, _ = get_namespace(X)
# --> 375 scores = self.decision_function(X)
#     376 if len(scores.shape) == 1:
#     377     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\linear_model\_base.py:352, in LinearClassifierMixin.decision_function(self, X)
# ...

# %%
pre

# %%
xnew_pre = pre.transform(xnew)
xnew_pre.head()

# %% [markdown]
# Final Predictions

# %%
species_predicted = model.predict(xnew_pre)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 species_predicted = model.predict(xnew_pre)
#
# NameError: name 'xnew_pre' is not defined

# %%
species_predicted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 species_predicted
#
# NameError: name 'species_predicted' is not defined

# %%
xnew
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 xnew
#
# NameError: name 'xnew' is not defined

# %%
xnew['predicted_species'] = species_predicted

# %%
xnew
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 xnew
#
# NameError: name 'xnew' is not defined

# %%
xnew.to_csv("Iris Species Predicted.csv",index=False)
